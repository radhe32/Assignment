# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# RADHE SHYAM THAKUR, SALES EXECUTIVE

# %% [markdown]
# I am interested in data science because I want to get my job role changed and salary to be hiked.

# %% [markdown]
# My code in the next cell is going to print "Hello Radhe, how are you?"

# %%
print("Hello Radhe, how are you?")
# Out:
# Hello Radhe, how are you?

# %% [markdown]
# ![MicrosoftTeams-image (7).png](attachment:0596cc9e-75bf-458b-bb81-4f7180f28dec.png) https://www.facebook.com/ ⁍ ‣
